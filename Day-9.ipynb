# %%
name=input()
year=int(input())
print(f'{name}@{year}')
# Out:
#  srinu
#  2000
# srinu@2000

# %%
name=input()
year=int(input())
res=name.lower() +"@"+ str(year)
print(res)
# Out:
#  SrinuBabu
#  2005
# srinubabu@2005
