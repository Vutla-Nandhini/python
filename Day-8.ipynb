# %%
s="nandhini"
print(s.upper())
print(s.lower())
# Out:
# NANDHINI
# nandhini

# %%
print(s.swapcase())
# Out:
# NANDHINI

# %%
print(s.capitalize())
# Out:
# Nandhini

# %%
print(s.title())
# Out:
# Nandhini

# %%
print(s)
# Out:
# nandhini

# %%
st="Pavani@Lakshmi"
print(st.capitalize())
print(st.title())
# Out:
# Pavani@lakshmi
# Pavani@Lakshmi

# %%
print(st.replace("@","-"))
# Out:
# Pavani-Lakshmi

# %%
print(st.split("@"))
# Out:
# ['Pavani', 'Lakshmi']

# %%
s2="The sky is blue and the ocean is blue"
print(s2.split(sep="-"))
print(s2.split(sep="blue"))
print(s2.split(" "))
# Out:
# ['The sky is blue and the ocean is blue']
# ['The sky is ', ' and the ocean is ', '']
# ['The', 'sky', 'is', 'blue', 'and', 'the', 'ocean', 'is', 'blue']

# %%
print(s2.index('is'))
print(s2.index("n"))
# Out:
# 8
# 17

# %%
print(s2.find('is'))
print(s2.find("Z"))
# Out:
# 8
# -1

# %%
#strip():it removes the leading and lagging white space
s3="           The sky is blue and the ocean is blue               "
print(s3.strip())
print(s3.lstrip())
print(s3.rstrip())
# Out:
# The sky is blue and the ocean is blue
# The sky is blue and the ocean is blue
#            The sky is blue and the ocean is blue

# %%
#'sep'.join(iterable) - it joins all elements in the iterable with separator
lst=['The', 'sky', 'is', 'blue', 'and', 'the', 'ocean', 'is', 'blue']
print(''.join(lst))
print(' '.join(lst))
print('@'.join(lst))
# Out:
# Theskyisblueandtheoceanisblue
# The sky is blue and the ocean is blue
# The@sky@is@blue@and@the@ocean@is@blue

# %%
#weather the password is strong or weak
password = input()
count=0
if(len(password>=8):
    if(password.isupper() and password.islower() and password.isdigit()):
        for item in "@$()#":
            if item in passwrd:
                count+=1
                print("The password is strong")
                break
else:
    print("weak Password")
# Out:
#   Cell In[1], line 4
#     if(len(password>=8):
#                        ^
# SyntaxError: invalid syntax
